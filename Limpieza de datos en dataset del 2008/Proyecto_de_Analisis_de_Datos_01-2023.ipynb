# %% [markdown]
# # Importamos nuestro Excel de las muertes ocurridas en 2008
#
# # Cargar Datos

# %%
import pandas as pd
file = "C:/Users/user/Desktop/ProyectosAnalisisdeDatos/2008_data.csv"
df = pd.read_csv(file, sep=';', header=0, skiprows=0, encoding='utf-8')
df
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_804\2924263626.py:3: DtypeWarning: Columns (39,40,41,42,43,44,45,46,60,61,62,63,64,65,66) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file, sep=';', header=0, skiprows=0, encoding='utf-8')
#          resident_status  education_1989_revision  education_2003_revision  \
# 0                      1                     12.0                      NaN
# 1                      1                      9.0                      NaN
# 2                      2                     14.0                      NaN
# 3                      2                     12.0                      NaN
# 4                      1                      6.0                      NaN
# ...                  ...                      ...                      ...
# 1048570                1                     12.0                      NaN
# 1048571                1                     17.0                      NaN
# ...

# %%
#Esta linea de codigo es para identificar las primera filas del dataframe
#print("las primeras 5 filas del dataframe") 
#df.head(5)

# %% [markdown]
# # Limpienza de Datos
# ### Agregar encabezados
# si nuestro dateset no tiene encabezados, desde python podemos agregarle las etiquetas, pero primero debemos eliminar filas inesecarias.

# %%
df.drop([0], axis=0, inplace=True)
df
# Out:
#          resident_status  education_1989_revision  education_2003_revision  \
# 1                      1                      9.0                      NaN
# 2                      2                     14.0                      NaN
# 3                      2                     12.0                      NaN
# 4                      1                      6.0                      NaN
# 5                      2                     12.0                      NaN
# ...                  ...                      ...                      ...
# 1048570                1                     12.0                      NaN
# 1048571                1                     17.0                      NaN
# 1048572                1                      7.0                      NaN
# 1048573                1                     12.0                      NaN
# 1048574                1                      8.0                      NaN
#
# ...

# %% [markdown]
# Agregamos los encabezados de la siguiente manera.

# %%
headers = ["estatus de residente","educación 1989 revisión","educación 2003 revisión","bandera de informes de educación","mes de la muerte", "sexo","tipo de edad",
         "edad del detalle","bandera de sustitución de edad","recodificar edad 52", "recodificar edad 27","recodificar edad 12","lugar de la muerte y estado de los difuntos","Estado civil","día de la semana de la muerte","Columna no nesecaria","Columna no nesecaria","Columna no nesecaria","Columna no nesecaria","Columna no nesecaria","Columna no nesecaria","Columna no nesecaria","Columna no nesecaria","Columna no nesecaria","Columna no nesecaria","Columna no nesecaria","Columna no nesecaria","Columna no nesecaria","Columna no nesecaria","Columna no nesecaria","Columna no nesecaria","Columna no nesecaria","Columna no nesecaria","Columna no nesecaria","Columna no nesecaria","Columna no nesecaria","Columna no nesecaria","Columna no nesecaria","Columna no nesecaria","Columna no nesecaria","Columna no nesecaria","Columna no nesecaria","Columna no nesecaria","Columna no nesecaria","Columna no nesecaria","Columna no nesecaria","Columna no nesecaria",
          "Columna no nesecaria","Columna no nesecaria","Columna no nesecaria","Columna no nesecaria","Columna no nesecaria","Columna no nesecaria","Columna no nesecaria","Columna no nesecaria","Columna no nesecaria","Columna no nesecaria","Columna no nesecaria","Columna no nesecaria","Columna no nesecaria","Columna no nesecaria","Columna no nesecaria","Columna no nesecaria"
          "Columna no nesecaria","Columna no nesecaria","Columna no nesecaria","Columna no nesecaria","Columna no nesecaria","Columna no nesecaria","Columna no nesecaria","Columna no nesecaria","Columna no nesecaria","Columna no nesecaria","Columna no nesecaria","Columna no nesecaria","Columna no nesecaria","Columna no nesecaria","Columna no nesecaria"]
print("headers\n", headers)
# Out:
# headers
# ...

# %% [markdown]
# Remplazamos el encabezado y miramos el data frame.

# %%
df.columns = headers
df.head(5)
# Out:
#    estatus de residente  educación 1989 revisión  educación 2003 revisión  \
# 1                     1                      9.0                      NaN
# 2                     2                     14.0                      NaN
# 3                     2                     12.0                      NaN
# 4                     1                      6.0                      NaN
# 5                     2                     12.0                      NaN
#
#    bandera de informes de educación  mes de la muerte sexo  tipo de edad  \
# 1                                 0                 1    M             1
# 2                                 0                 1    F             1
# 3                                 0                 1    M             1
# 4                                 0                 1    F             1
# 5                                 0                 1    F             1
#
#    edad del detalle  bandera de sustitución de edad  recodificar edad 52  ...  \
# ...

# %%
df.drop(['Columna no nesecaria'], axis=1)
# Out:
#          estatus de residente  educación 1989 revisión  \
# 1                           1                      9.0
# 2                           2                     14.0
# 3                           2                     12.0
# 4                           1                      6.0
# 5                           2                     12.0
# ...                       ...                      ...
# 1048570                     1                     12.0
# 1048571                     1                     17.0
# 1048572                     1                      7.0
# 1048573                     1                     12.0
# 1048574                     1                      8.0
#
#          educación 2003 revisión  bandera de informes de educación  \
# 1                            NaN                                 0
# 2                            NaN                                 0
# 3                            NaN                                 0
# ...

# %% [markdown]
# Remplazamos el simpbolo ? por el NaN

# %%
import numpy as np
df=df.replace('?',np.NaN)

# %%
df=df.dropna(subset=["educación 1989 revisión"], axis=0)
df.head(20)
# Out:
#     estatus de residente  educación 1989 revisión  educación 2003 revisión  \
# 1                      1                      9.0                      NaN
# 2                      2                     14.0                      NaN
# 3                      2                     12.0                      NaN
# 4                      1                      6.0                      NaN
# 5                      2                     12.0                      NaN
# 6                      1                     12.0                      NaN
# 7                      1                     16.0                      NaN
# 8                      1                      8.0                      NaN
# 9                      1                      8.0                      NaN
# 10                     1                     10.0                      NaN
# 11                     1                     12.0                      NaN
# ...

# %%
print(df.columns)
# Out:
# Index(['estatus de residente', 'educación 1989 revisión',
#        'educación 2003 revisión', 'bandera de informes de educación',
#        'mes de la muerte', 'sexo', 'tipo de edad', 'edad del detalle',
#        'bandera de sustitución de edad', 'recodificar edad 52',
#        'recodificar edad 27', 'recodificar edad 12',
#        'lugar de la muerte y estado de los difuntos', 'Estado civil',
#        'día de la semana de la muerte', 'Columna no nesecaria',
#        'Columna no nesecaria', 'Columna no nesecaria', 'Columna no nesecaria',
#        'Columna no nesecaria', 'Columna no nesecaria', 'Columna no nesecaria',
#        'Columna no nesecaria', 'Columna no nesecaria', 'Columna no nesecaria',
#        'Columna no nesecaria', 'Columna no nesecaria', 'Columna no nesecaria',
#        'Columna no nesecaria', 'Columna no nesecaria', 'Columna no nesecaria',
#        'Columna no nesecaria', 'Columna no nesecaria', 'Columna no nesecaria',
# ...

# %%
# se chequea el tipo de datos de las columnas 
print(df.dtypes)
# Out:
# estatus de residente                  int64
# educación 1989 revisión             float64
# educación 2003 revisión             float64
# bandera de informes de educación      int64
# mes de la muerte                      int64
#                                      ...
# Columna no nesecaria                float64
# Columna no nesecaria                  int64
# Columna no nesecaria                  int64
# Columna no nesecaria                  int64
# Columna no nesecaria                  int64
# Length: 77, dtype: object

# %% [markdown]
# La funciòn Describe() lanza los metodos estadisticos de nuestra tabla importada

# %%
df.describe()
# Out:
#        estatus de residente  educación 1989 revisión  educación 2003 revisión  \
# count         306330.000000            306330.000000                      0.0
# mean               1.230167                12.933594                      NaN
# std                0.503618                11.252474                      NaN
# min                1.000000                 0.000000                      NaN
# 25%                1.000000                11.000000                      NaN
# 50%                1.000000                12.000000                      NaN
# 75%                1.000000                14.000000                      NaN
# max                4.000000                99.000000                      NaN
#
#        bandera de informes de educación  mes de la muerte   tipo de edad  \
# count                          306330.0     306330.000000  306330.000000
# mean                                0.0          6.330954       1.032289
# ...

# %% [markdown]
# Con la siguiente funcion puede ver el datalle de las columnas

# %%
df.describe(include = "all")
# Out:
#         estatus de residente  educación 1989 revisión  \
# count          306330.000000            306330.000000
# unique                   NaN                      NaN
# top                      NaN                      NaN
# freq                     NaN                      NaN
# mean                1.230167                12.933594
# std                 0.503618                11.252474
# min                 1.000000                 0.000000
# 25%                 1.000000                11.000000
# 50%                 1.000000                12.000000
# 75%                 1.000000                14.000000
# max                 4.000000                99.000000
#
#         educación 2003 revisión  bandera de informes de educación  \
# count                       0.0                          306330.0
# unique                      NaN                               NaN
# top                         NaN                               NaN
# ...

# %% [markdown]
# Tambien podemos ver el detalle estadistico en solo unas columnas

# %%
df[['sexo'] ].describe()
# Out:
#           sexo
# count   306330
# unique       2
# top          M
# freq    153494

# %% [markdown]
# Otro metodo para mirar el detalle de la tabla es :

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 306330 entries, 1 to 1048574
# Data columns (total 77 columns):
#  #   Column                                       Non-Null Count   Dtype
# ---  ------                                       --------------   -----
#  0   estatus de residente                         306330 non-null  int64
#  1   educación 1989 revisión                      306330 non-null  float64
#  2   educación 2003 revisión                      0 non-null       float64
#  3   bandera de informes de educación             306330 non-null  int64
#  4   mes de la muerte                             306330 non-null  int64
#  5   sexo                                         306330 non-null  object
#  6   tipo de edad                                 306330 non-null  int64
#  7   edad del detalle                             306330 non-null  int64
#  8   bandera de sustitución de edad               5 non-null       float64
# ...

# %% [markdown]
# Para manejar valores faltantes y estandarizar, normalizar los datos.
# Debemos hacer lo siguiente

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- ---------
# anyio                         3.6.2
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# args                          0.1.0
# arrow                         1.2.3
# asttokens                     2.2.1
# attrs                         22.2.0
# backcall                      0.2.0
# beautifulsoup4                4.11.2
# bleach                        6.0.0
# blinker                       1.6.2
# certifi                       2022.12.7
# cffi                          1.15.1
# charset-normalizer            3.1.0
# click                         8.1.3
# clint                         0.5.1
# cloudpickle                   2.2.1
# colorama                      0.4.6
# comm                          0.1.2
# contourpy                     1.0.7
# coverage                      7.2.2
# cycler                        0.11.0
# debugpy                       1.6.6
# ...

# %%
import matplotlib.pylab as plt
import micropip

# %%
# Para ver cómo se ve el conjunto de datos, usaremos el método head().
df.head()
# Out:
#    estatus de residente  educación 1989 revisión  educación 2003 revisión  \
# 1                     1                      9.0                      NaN
# 2                     2                     14.0                      NaN
# 3                     2                     12.0                      NaN
# 4                     1                      6.0                      NaN
# 5                     2                     12.0                      NaN
#
#    bandera de informes de educación  mes de la muerte sexo  tipo de edad  \
# 1                                 0                 1    M             1
# 2                                 0                 1    F             1
# 3                                 0                 1    M             1
# 4                                 0                 1    F             1
# 5                                 0                 1    F             1
#
#    edad del detalle  bandera de sustitución de edad  recodificar edad 52  ...  \
# ...

# %% [markdown]
# <h2 id="identify_handle_missing_values">Identificar y manejar valores perdidos</h2>
#
# <h3 id="identify_missing_values">Identificar valores perdidos</h3>
# <h4>Convertir "?" a NaN</h4>
# En el conjunto de datos del automóvil, los datos faltantes vienen con el signo de interrogación "?".
# Reemplazamos "?" con NaN (No es un número), el marcador de valor faltante predeterminado de Python por razones de conveniencia y velocidad computacional. Aquí usamos la función:
#   <pre>.replace(A, B, en lugar = Verdadero) </pre>
# para reemplazar A por B.

# %%
import numpy as np

# remplaza "?" por NaN
df.replace("?", np.nan, inplace = True)
df.head(5)
# Out:
#    estatus de residente  educación 1989 revisión  educación 2003 revisión  \
# 1                     1                      9.0                      NaN
# 2                     2                     14.0                      NaN
# 3                     2                     12.0                      NaN
# 4                     1                      6.0                      NaN
# 5                     2                     12.0                      NaN
#
#    bandera de informes de educación  mes de la muerte sexo  tipo de edad  \
# 1                                 0                 1    M             1
# 2                                 0                 1    F             1
# 3                                 0                 1    M             1
# 4                                 0                 1    F             1
# 5                                 0                 1    F             1
#
#    edad del detalle  bandera de sustitución de edad  recodificar edad 52  ...  \
# ...

# %% [markdown]
# <h4>Evaluación de datos faltantes</h4>
#
# Los valores que faltan se convierten de forma predeterminada. Usamos las siguientes funciones para identificar estos valores faltantes. Existen dos métodos para detectar datos faltantes:
#
# <ol>
#      <li><b>.isnull()</b></li>
#      <li><b>.notnull()</b></li>
# </ol>
# La salida es un valor booleano que indica si el valor que se pasa al argumento es de hecho falta de datos.

# %%
missing_data = df.isnull()
missing_data.head(5)
# Out:
#    estatus de residente  educación 1989 revisión  educación 2003 revisión  \
# 1                 False                    False                     True
# 2                 False                    False                     True
# 3                 False                    False                     True
# 4                 False                    False                     True
# 5                 False                    False                     True
#
#    bandera de informes de educación  mes de la muerte   sexo  tipo de edad  \
# 1                             False             False  False         False
# 2                             False             False  False         False
# 3                             False             False  False         False
# 4                             False             False  False         False
# 5                             False             False  False         False
#
# ...

# %% [markdown]
# "Verdadero" significa que el valor es un valor perdido, mientras que "Falso" significa que el valor no es un valor perdido.

# %% [markdown]
# # Datos Estadisticos
# <h4>Cuenta los valores que faltan en cada columna</h4>
# <p>
# Usando un bucle for en Python, podemos calcular rápidamente la cantidad de valores que faltan en cada columna. Como se mencionó anteriormente, "Verdadero" representa un valor faltante y "Falso" significa que el valor está presente en el conjunto de datos. En el cuerpo del bucle for, el método ".value_counts()" cuenta el número de valores "Verdaderos".
# </p>

# %%
for column in missing_data.columns.values.tolist():
    print(column)
    print (missing_data[column].value_counts())
    print("")
# Out:
# estatus de residente
# False    306330
# Name: estatus de residente, dtype: int64
#
# educación 1989 revisión
# False    306330
# Name: educación 1989 revisión, dtype: int64
#
# educación 2003 revisión
# True    306330
# Name: educación 2003 revisión, dtype: int64
#
# bandera de informes de educación
# False    306330
# Name: bandera de informes de educación, dtype: int64
#
# mes de la muerte
# False    306330
# Name: mes de la muerte, dtype: int64
#
# sexo
# False    306330
# Name: sexo, dtype: int64
#
# tipo de edad
# False    306330
# Name: tipo de edad, dtype: int64
#
# edad del detalle
# False    306330
# Name: edad del detalle, dtype: int64
#
# bandera de sustitución de edad
# True     306325
# False         5
# Name: bandera de sustitución de edad, dtype: int64
#
# recodificar edad 52
# False    306330
# Name: recodificar edad 52, dtype: int64
#
# recodificar edad 27
# False    306330
# Name: recodificar edad 27, dtype: int64
#
# recodificar edad 12
# False    306330
# ...

# %%
# !mamba install numpy=1.21.2
# Out:
# 0 examples ran in 0.0010 seconds

# %% [markdown]
# <h4>Calcule el valor medio de la columna "pérdidas normalizadas" </h4>

# %%
avg_norm_loss = df["edad del detalle"].astype("float").mean(axis=0)
# variable = df[(la columna a evaluar)]
print("Promedio de sexo:", avg_norm_loss)
#realizamos un promedio de perdidas mean signifaca promedio
# Out:
# Promedio de sexo: 72.31631900238305

# %% [markdown]
# <h4>Reemplace "NaN" con el valor medio en la columna "pérdidas normalizadas"</h4>

# %%
df["educación 2003 revisión"].replace(np.nan, avg_norm_loss, inplace=True)
#df[(la columna a evaluar)]
#Como lo dice el nombre se remplaza NaN Por el valor calculado arriba

# %% [markdown]
# <h4>Calcule el valor medio para la columna "mes de la muerte"</h4>

# %%
avg_bore=df['mes de la muerte'].astype('float').mean(axis=0)
# variable = df[(columna a calcular)]
print("Average of bore:", avg_bore)
# de igual forma se calcula el promedio
# Out:
# Average of bore: 6.330953546828583

# %% [markdown]
# <h4>Reemplace "NaN" con el valor medio en la columna "mes de la muerter"</h4>

# %%
df["mes de la muerte"].replace(np.nan, avg_bore, inplace=True)
#df[(columna a calcular)] y se remplaza por el valor que obtuvimos anteriorente

# %% [markdown]
# Para ver qué valores están presentes en una columna en particular, podemos usar el método ".value_counts()":

# %%
df['sexo'].value_counts()
# valores estadisticos
# Out:
# M    153494
# F    152836
# Name: sexo, dtype: int64

# %%
df['edad del detalle'].value_counts()
# valores estadisticos
# Out:
# 86     9749
# 85     9547
# 83     9408
# 87     9242
# 84     9232
#        ...
# 110       5
# 111       2
# 117       1
# 112       1
# 113       1
# Name: edad del detalle, Length: 115, dtype: int64

# %%
df['mes de la muerte'].value_counts()
# valores estadisticos
# Out:
# 1     30206
# 3     28586
# 2     27244
# 12    26747
# 4     25568
# 5     25034
# 11    24923
# 10    24645
# 8     23570
# 6     23479
# 7     23243
# 9     23085
# Name: mes de la muerte, dtype: int64

# %% [markdown]
# Podemos ver que cuatro puertas son el tipo más común. También podemos usar el método ".idxmax()" para calcular automáticamente el tipo más común:

# %%
df['mes de la muerte'].value_counts().idxmax()
#es como la moda de una columna
# Out:
# 1

# %%
df['edad del detalle'].value_counts().idxmax()
#es como la moda de una columna
# Out:
# 86

# %%
df['sexo'].value_counts().idxmax()
#es como la moda de una columna
# Out:
# 'M'

# %% [markdown]
# El procedimiento de sustitución es muy similar al que hemos visto anteriormente:

# %%
#reemplace los valores faltantes de 'número de puertas' por los más frecuentes
df["edad del detalle"].replace(np.nan, "four", inplace=True)
#df[(columna a calcular)] y se remplaza por el valor que obtuvimos anteriorente que en este caso es por las puertas mas frecuentes

# %% [markdown]
# Finalmente, eliminemos todas las filas que no tienen datos de precios:

# %%
# simplemente suelte toda la fila con NaN en la columna "precio"
df.dropna(subset=["educación 2003 revisión"], axis=0, inplace=True)

# restablecer el índice, porque eliminamos dos filas
df.reset_index(drop=True, inplace=True)

# %%
df.head(5)
#Imprime la tabla
# Out:
#    estatus de residente  educación 1989 revisión  educación 2003 revisión  \
# 0                     1                      9.0                72.316319
# 1                     2                     14.0                72.316319
# 2                     2                     12.0                72.316319
# 3                     1                      6.0                72.316319
# 4                     2                     12.0                72.316319
#
#    bandera de informes de educación  mes de la muerte sexo  tipo de edad  \
# 0                                 0                 1    M             1
# 1                                 0                 1    F             1
# 2                                 0                 1    M             1
# 3                                 0                 1    F             1
# 4                                 0                 1    F             1
#
#    edad del detalle  bandera de sustitución de edad  recodificar edad 52  ...  \
# ...

# %% [markdown]
# <h3 id="correct_data_format">Formato de datos correcto</h3>
# <b>¡Ya casi llegamos!</b>
# <p>El último paso en la limpieza de datos es verificar y asegurarse de que todos los datos estén en el formato correcto (int, float, text u otro).</p>
#
# En Pandas, usamos:
#
# <p><b>.dtype()</b> para comprobar el tipo de datos</p>
# <p><b>.astype()</b> para cambiar el tipo de datos</p>

# %%
df.dtypes
# Out:
# estatus de residente                  int64
# educación 1989 revisión             float64
# educación 2003 revisión             float64
# bandera de informes de educación      int64
# mes de la muerte                      int64
#                                      ...
# Columna no nesecaria                float64
# Columna no nesecaria                  int64
# Columna no nesecaria                  int64
# Columna no nesecaria                  int64
# Columna no nesecaria                  int64
# Length: 77, dtype: object

# %% [markdown]
# Como podemos ver arriba, algunas columnas no tienen el tipo de datos correcto. Las variables numéricas deben tener el tipo 'flotante' o 'int', y las variables con cadenas, como las categorías, deben tener el tipo 'objeto'. Por ejemplo, las variables 'mes de la muerte' y 'bandera de informes de educaciòn' son valores numéricos que describen valores cuantitativos, por lo que deberíamos esperar que sean del tipo 'flotante' o 'int'; sin embargo, se muestran como tipo 'objeto'. Tenemos que convertir los tipos de datos a un formato adecuado para cada columna usando el método "astype()".

# %% [markdown]
# <h4>Convertir tipos de datos al formato adecuado</h4>

# %%
# Se ejecuta esta parte del codigo si estuviera un valor tipo object
"""
df[["bore", "stroke"]] = df[["bore", "stroke"]].astype("float")
df[["normalized-losses"]] = df[["normalized-losses"]].astype("int")
df[["price"]] = df[["price"]].astype("float")
df[["peak-rpm"]] = df[["peak-rpm"]].astype("float")
"""
# Out:
# '\ndf[["bore", "stroke"]] = df[["bore", "stroke"]].astype("float")\ndf[["normalized-losses"]] = df[["normalized-losses"]].astype("int")\ndf[["price"]] = df[["price"]].astype("float")\ndf[["peak-rpm"]] = df[["peak-rpm"]].astype("float")\n'

# %% [markdown]
# <h2 id="data_standardization">Estandarización de datos</h2>
# <p>
# Los datos generalmente se recopilan de diferentes agencias en diferentes formatos.
# (La estandarización de datos también es un término para un tipo particular de normalización de datos donde restamos la media y dividimos por la desviación estándar).
# </p>
#
# <b>¿Qué es la estandarización?</b>
#
# <p>La estandarización es el proceso de transformar los datos en un formato común, lo que permite al investigador realizar una comparación significativa.
# </p>
#
# <b>Ejemplo</b>
#
# <p>Transformar mpg a L/100km:</p>
# <p>En nuestro conjunto de datos, las columnas de consumo de combustible "mpg en ciudad" y "mpg en carretera" están representadas por unidades de mpg (millas por galón). Supongamos que estamos desarrollando una aplicación en un país que acepta el consumo de combustible con el estándar L/100km.</p>
# <p>Tendremos que aplicar <b>transformación de datos</b> para transformar mpg en L/100km.</p>

# %% [markdown]
# <p>La fórmula para la conversión de unidades es:<p>
# L/100km = 235 / millas por galón
# <p>Podemos hacer muchas operaciones matemáticas directamente en Pandas.</p>

# %%
# Convierta mpg a L/100km por operación matemática (235 dividido por mpg)
#df['city-L/100km'] = 235/df["city-mpg"]

# verifique sus datos transformados
#df.head()

# %%
df.head()
# Out:
#    estatus de residente  educación 1989 revisión  educación 2003 revisión  \
# 0                     1                      9.0                72.316319
# 1                     2                     14.0                72.316319
# 2                     2                     12.0                72.316319
# 3                     1                      6.0                72.316319
# 4                     2                     12.0                72.316319
#
#    bandera de informes de educación  mes de la muerte sexo  tipo de edad  \
# 0                                 0                 1    M             1
# 1                                 0                 1    F             1
# 2                                 0                 1    M             1
# 3                                 0                 1    F             1
# 4                                 0                 1    F             1
#
#    edad del detalle  bandera de sustitución de edad  recodificar edad 52  ...  \
# ...

# %% [markdown]
# <h2 id="data_normalization">Normalización de datos</h2>
#
# <b>¿Por qué normalizar?</b>
#
# <p>La normalización es el proceso de transformar valores de varias variables en un rango similar. Las normalizaciones típicas incluyen escalar la variable para que el promedio de la variable sea 0, escalar la variable para que la varianza sea 1 o escalar la variable para que los valores de la variable oscilen entre 0 y 1.
# </p>
#
# <b>Ejemplo</b>
#
# <p>Para demostrar la normalización, digamos que queremos escalar las columnas "largo", "ancho" y "alto".</p>
# <p><b>Objetivo:</b> le gustaría normalizar esas variables para que su valor oscile entre 0 y 1</p>
# <p><b>Enfoque:</b> reemplazar el valor original por (valor original)/(valor máximo)</p>

# %%
# reemplazar (valor original) por (valor original)/(valor máximo)
#df['edad del detalle'] = df['edad del detalle']/df['edad del detalle'].max()

# %%
df['edad del detalle'].head()
# Out:
# 0    78
# 1    83
# 2    54
# 3    61
# 4    41
# Name: edad del detalle, dtype: int64

# %% [markdown]
# <h2 id="binning">Agrupación</h2>
#
# <b>¿Por qué agrupar?</b>
# <p>
#      El agrupamiento es un proceso de transformación de variables numéricas continuas en 'contenedores' categóricos discretos para el análisis agrupado.
# </p>
#
# <b>Ejemplo: </b>
#
# <p>En nuestro conjunto de datos, "caballos de fuerza" es una variable de valor real que va de 48 a 288 y tiene 59 valores únicos. ¿Qué pasa si solo nos preocupamos por la diferencia de precio entre autos de alta potencia, potencia media y poca potencia (3 tipos)? ¿Podemos reorganizarlos en tres "contenedores" para simplificar el análisis? </p>
#
# <p>Usaremos el método de pandas 'cortar' para segmentar la columna 'caballos de fuerza' en 3 contenedores.</p>

# %%
df["edad del detalle"]=df["edad del detalle"].astype(int, copy=True)

# %% [markdown]
# Tracemos el histograma de edad para ver cómo se ve la distribución la edad.

# %%
""""
import piplite
await piplite.install('numpy')
await piplite.install('pandas')
await piplite.install('matplotlib')
await piplite.install('bokeh')
await piplite.install(['pandas'])
await piplite.install(['matplotlib'])
await piplite.install(['skillsnetwork'])
"""
# Out:
# '"\nimport piplite\nawait piplite.install(\'numpy\')\nawait piplite.install(\'pandas\')\nawait piplite.install(\'matplotlib\')\nawait piplite.install(\'bokeh\')\nawait piplite.install([\'pandas\'])\nawait piplite.install([\'matplotlib\'])\nawait piplite.install([\'skillsnetwork\'])\n'

# %%
pip install matplotlib
# Out:
# ...
#
# ...

# %%
#%matplotlib inline # importamos la librerias correspondientes 
import matplotlib as plt
from matplotlib import pyplot
plt.pyplot.hist(df["edad del detalle"],50)# determinamos a que columna deseamos hacer el histograma 

# establecer etiquetas x/y y título de trama
plt.pyplot.xlabel("edad del detalle")# Titulo 
plt.pyplot.ylabel("Cantidad")# Eje y 
plt.pyplot.title("edad del detalle")# Eje x
plt.pyplot.xlim(0,150)
# Out:
# (0.0, 150.0)

# %% [markdown]
# <p>Nos gustaría 3 contenedores de ancho de banda del mismo tamaño, por lo que usamos la función <code>linspace(start_value, end_value, numbers_generated</code>) de numpy.</p>
# <p>Dado que queremos incluir el valor mínimo de caballos de fuerza, queremos establecer start_value = min(df["edad del detalle"]).</p>
# <p>Dado que queremos incluir el valor máximo de caballos de fuerza, queremos establecer end_value = max(df["edad del detalle"]).</p>
# <p>Dado que estamos construyendo 3 contenedores de igual longitud, debe haber 4 divisores, por lo que los números_generados = 4.</p>

# %%
bins = np.linspace(min(df["edad del detalle"]), max(df["edad del detalle"]), 4)
#Nos gustaría 3 contenedores de ancho de banda del mismo tamaño
bins
#Mostramos los resultados
# Out:
# array([  1.        , 333.66666667, 666.33333333, 999.        ])

# %% [markdown]
# Establecemos nombres de grupo:

# %%
group_names = ['Low', 'Medium', 'High']

# %% [markdown]
# Aplicamos la función "cut" para determinar a qué pertenece cada valor de `df['edad del detalles']`.

# %%
df['edad del detalle-binned'] = pd.cut(df['edad del detalle'], bins, labels=group_names, include_lowest=True )
df[['edad del detalle-binned','edad del detalle']].head(100)
# Out:
#    edad del detalle-binned  edad del detalle
# 0                      Low                78
# 1                      Low                83
# 2                      Low                54
# 3                      Low                61
# 4                      Low                41
# ..                     ...               ...
# 95                     Low                16
# 96                     Low                67
# 97                     Low                59
# 98                     Low                42
# 99                     Low                72
#
# [100 rows x 2 columns]

# %% [markdown]
# Veamos el número  en cada contenedor:

# %%
df["edad del detalle-binned"].value_counts()
# Out:
# Low       306312
# High          18
# Medium         0
# Name: edad del detalle-binned, dtype: int64

# %% [markdown]
# Tracemos la distribución de cada contenedor:

# %%
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot
pyplot.bar(group_names, df["edad del detalle-binned"].value_counts())

# set x/y etiquetas y titulo  plot 
plt.pyplot.xlabel("edad del detalle")
plt.pyplot.ylabel("Cantidad")
plt.pyplot.title("edad del detalle-binned ")
# Out:
# Text(0.5, 1.0, 'edad del detalle-binned ')

# %% [markdown]
# <p>
#      Mire el marco de datos de arriba con cuidado. Encontrará que la última columna proporciona los contenedores para "caballos de fuerza" basados en 3 categorías ("Bajo", "Medio" y "Alto").
# </p>

# %% [markdown]
# <h3>Visualización de contenedores</h3>
# Normalmente, se usa un histograma para visualizar la distribución de los contenedores que creamos anteriormente.

# %%
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot


# dibuja el histograma del atributo "caballos de fuerza" con contenedores = 3
plt.pyplot.hist(df["edad del detalle"], bins = 3)

# establecer etiquetas x/y y título de trama
plt.pyplot.xlabel("edad del detalle")
plt.pyplot.ylabel("cantidad")
plt.pyplot.title("edad del detalle bins")
# Out:
# Text(0.5, 1.0, 'edad del detalle bins')

# %% [markdown]
# El gráfico anterior muestra el resultado de clasificación para el atributo "caballos de fuerza".

# %% [markdown]
# <h2 id="indicator">Variable indicadora (o variable ficticia)</h2>
# <b>¿Qué es una variable indicadora?</b>
# <p>
#      Una variable indicadora (o variable ficticia) es una variable numérica utilizada para etiquetar categorías. Se les llama 'tontos' porque los números en sí mismos no tienen un significado inherente.
# </p>
#
# <b>¿Por qué usamos variables indicadoras?</b>
#
# <p>
#      Usamos variables indicadoras para poder usar variables categóricas para el análisis de regresión en los módulos posteriores.
# </p>
# <b>Ejemplo</b>
# <p>
#      Vemos que la columna "tipo de combustible" tiene dos valores únicos: "gas" o "diésel". La regresión no entiende de palabras, sólo de números. Para usar este atributo en el análisis de regresión, convertimos "tipo de combustible" en variables indicadoras.
# </p>
#
# <p>
#      Usaremos el método de pandas 'get_dummies' para asignar valores numéricos a diferentes categorías de tipo de combustible.
# </p>

# %%
df.columns
# Out:
# Index(['estatus de residente', 'educación 1989 revisión',
#        'educación 2003 revisión', 'bandera de informes de educación',
#        'mes de la muerte', 'sexo', 'tipo de edad', 'edad del detalle',
#        'bandera de sustitución de edad', 'recodificar edad 52',
#        'recodificar edad 27', 'recodificar edad 12',
#        'lugar de la muerte y estado de los difuntos', 'Estado civil',
#        'día de la semana de la muerte', 'Columna no nesecaria',
#        'Columna no nesecaria', 'Columna no nesecaria', 'Columna no nesecaria',
#        'Columna no nesecaria', 'Columna no nesecaria', 'Columna no nesecaria',
#        'Columna no nesecaria', 'Columna no nesecaria', 'Columna no nesecaria',
#        'Columna no nesecaria', 'Columna no nesecaria', 'Columna no nesecaria',
#        'Columna no nesecaria', 'Columna no nesecaria', 'Columna no nesecaria',
#        'Columna no nesecaria', 'Columna no nesecaria', 'Columna no nesecaria',
# ...

# %% [markdown]
# Obtenga las variables del indicador y asígnelas al marco de datos "dummy_variable\_1":

# %%
dummy_variable_1 = pd.get_dummies(df["sexo"])
dummy_variable_1.head()
# Out:
#    F  M
# 0  0  1
# 1  1  0
# 2  0  1
# 3  1  0
# 4  1  0

# %% [markdown]
# Cambie los nombres de las columnas para mayor claridad:

# %%
dummy_variable_1.rename(columns={'F':'Femenino', 'M':'Masculino'}, inplace=True)
dummy_variable_1.head()
# Out:
#    Femenino  Masculino
# 0         0          1
# 1         1          0
# 2         0          1
# 3         1          0
# 4         1          0

# %% [markdown]
# En el marco de datos, la columna 'sexo' tiene valores para 'Femenino' y 'Masculino' como 0 y 1 ahora.

# %%
# combine el marco de datos "df" y "dummy_variable_1"
df = pd.concat([df, dummy_variable_1], axis=1)

#elimine la columna original "sexo" de "df"
df.drop("sexo", axis = 1, inplace=True)

# %%
df.head()
# Out:
#    estatus de residente  educación 1989 revisión  educación 2003 revisión  \
# 0                     1                      9.0                72.316319
# 1                     2                     14.0                72.316319
# 2                     2                     12.0                72.316319
# 3                     1                      6.0                72.316319
# 4                     2                     12.0                72.316319
#
#    bandera de informes de educación  mes de la muerte  tipo de edad  \
# 0                                 0                 1             1
# 1                                 0                 1             1
# 2                                 0                 1             1
# 3                                 0                 1             1
# 4                                 0                 1             1
#
#    edad del detalle  bandera de sustitución de edad  recodificar edad 52  \
# ...

# %%
#Si ejecuta el laboratorio localmente con Anaconda, puede cargar la biblioteca y las versiones correctas descomentando lo siguiente:
#instalar una versión específica de las bibliotecas utilizadas en el laboratorio
# !mamba install pandas==1.3.3
# !mamba install numpy=1.21.2
# !mamba install scipy=1.7.1-y
# !mamba install seaborn=0.9.0-y
# Out:
# 0 examples ran in 0.0000 seconds
#
#
# 0 examples ran in 0.0000 seconds
#
#
# 0 examples ran in 0.0000 seconds
#
#
# 0 examples ran in 0.0000 seconds

# %%
import pandas as pd
import numpy as np
#import piplite
import skillsnetwork

# %% [markdown]
# <h2 id="pattern_visualization">2. Análisis de patrones de características individuales mediante visualización</h2>

# %% [markdown]
# Para instalar Seaborn usamos pip, el administrador de paquetes de Python.
# Importe los paquetes de visualización "Matplotlib" y "Seaborn". No se olvide de "% matplotlib inline" para trazar en un cuaderno Jupyter.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# <h4>¿Cómo elegir el método de visualización correcto?</h4>
# <p>Al visualizar variables individuales, es importante comprender primero con qué tipo de variable se está tratando. Esto nos ayudará a encontrar el método de visualización adecuado para esa variable.</p>

# %%
# enumerar los tipos de datos para cada columna
print(df.dtypes)
# Out:
# estatus de residente                   int64
# educación 1989 revisión              float64
# educación 2003 revisión              float64
# bandera de informes de educación       int64
# mes de la muerte                       int64
#                                       ...
# Columna no nesecaria                   int64
# Columna no nesecaria                   int64
# edad del detalle-binned             category
# Femenino                               uint8
# Masculino                              uint8
# Length: 79, dtype: object

# %% [markdown]
# ## ¿Qué es la correlación?
# La correlación es un tipo de asociación entre dos variables numéricas, específicamente evalúa la tendencia (creciente o decreciente) en los datos.
#
# Dos variables están asociadas cuando una variable nos da información acerca de la otra. Por el contrario, cuando no existe asociación, el aumento o disminución de una variable no nos dice nada sobre el comportamiento de la otra variable.
#
# Dos variables se correlacionan cuando muestran una tendencia creciente o decreciente.
#
# NOTA: Te recomiendo siempre comenzar a analizar la correlación realizando un diagrama de dispersión entre las variables que quieres analizar, te evitarás posibles problemas como el del ejemplo del cuarteto de Anscombe que les comenté en este post.

# %% [markdown]
# Por ejemplo, podemos calcular la correlación entre variables de tipo "int64" o "float64" usando el método "corr":

# %%
df.corr()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_3616\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                                              estatus de residente  \
# estatus de residente                                     1.000000
# educación 1989 revisión                                 -0.010961
# educación 2003 revisión                                       NaN
# bandera de informes de educación                              NaN
# mes de la muerte                                        -0.000862
# tipo de edad                                             0.041728
# edad del detalle                                        -0.111826
# bandera de sustitución de edad                                NaN
# recodificar edad 52                                     -0.109078
# ...

# %% [markdown]
# Los elementos diagonales son siempre uno; estudiaremos la correlación con más precisión la correlación de Pearson en profundidad al final del cuaderno.

# %%
df[['estatus de residente', 'educación 1989 revisión', 'mes de la muerte', 'edad del detalle']].corr()
# Out:
#                          estatus de residente  educación 1989 revisión  \
# estatus de residente                 1.000000                -0.010961
# educación 1989 revisión             -0.010961                 1.000000
# mes de la muerte                    -0.000862                -0.003002
# edad del detalle                    -0.111826                 0.038538
#
#                          mes de la muerte  edad del detalle
# estatus de residente            -0.000862         -0.111826
# educación 1989 revisión         -0.003002          0.038538
# mes de la muerte                 1.000000         -0.013102
# edad del detalle                -0.013102          1.000000

# %% [markdown]
# <h2>Variables numéricas continuas:</h2>
#
# <p>Las variables numéricas continuas son variables que pueden contener cualquier valor dentro de algún rango. Pueden ser del tipo "int64" o "float64". Una excelente forma de visualizar estas variables es mediante diagramas de dispersión con líneas ajustadas.</p>
#
# <p>Para comenzar a comprender la relación (lineal) entre una variable individual y el precio, podemos usar "regplot" que traza el diagrama de dispersión más la línea de regresión ajustada para los datos.</p>

# %% [markdown]
# Veamos varios ejemplos de diferentes relaciones lineales:

# %% [markdown]
# <h3>Relación lineal positiva</h3>

# %% [markdown]
# Encontremos el diagrama de dispersión de "sexo" y "edad".

# %%
# # Tamaño del motor como potencial variable predictora del precio
sns.regplot(x="edad del detalle", y="edad del detalle", data=df)
plt.ylim(0,)
# Out:
# (0.0, 1048.9000000002397)

# %% [markdown]
# Podemos examinar la correlación entre 'edad del detalle', 'tipo de edad' y ver que es aproximadamente 0,87.

# %%
df[["edad del detalle", "tipo de edad"]].corr()
# Out:
#                   edad del detalle  tipo de edad
# edad del detalle           1.00000      -0.22996
# tipo de edad              -0.22996       1.00000

# %% [markdown]
# El mpg en carretera es una variable predictiva potencial del precio. Encontremos el diagrama de dispersión de "mpg en carretera" y "precio".

# %%
sns.regplot(x="estatus de residente", y="edad del detalle", data=df)
# Out:
# <Axes: xlabel='estatus de residente', ylabel='edad del detalle'>

# %% [markdown]
# <h2 id="discriptive_statistics">3. Análisis estadístico descriptivo</h2>

# %% [markdown]
# <p>Primero echemos un vistazo a las variables utilizando un método de descripción.</p>
#
# <p>La función <b>describe</b> calcula automáticamente estadísticas básicas para todas las variables continuas. Cualquier valor de NaN se omite automáticamente en estas estadísticas.</p>
#
# Esto mostrará:
#
# <ul>
#      <li>el recuento de esa variable</li>
#      <li>la media</li>
#      <li>la desviación estándar (std)</li>
#      <li>el valor mínimo</li>
#      <li>el IQR (rango intercuartílico: 25 %, 50 % y 75 %)</li>
#      <li>el valor máximo</li>
# <ul>

# %%
df.describe()
# Out:
#        resident_status  education_1989_revision  education_2003_revision  \
# count     1.048575e+06            306331.000000            742244.000000
# mean      1.225806e+00                12.933591                 3.999209
# std       4.976773e-01                11.252456                 2.390596
# min       1.000000e+00                 0.000000                 1.000000
# 25%       1.000000e+00                11.000000                 3.000000
# 50%       1.000000e+00                12.000000                 3.000000
# 75%       1.000000e+00                14.000000                 5.000000
# max       4.000000e+00                99.000000                 9.000000
#
#        education_reporting_flag  month_of_death  detail_age_type  \
# count              1.048575e+06    1.048575e+06     1.048575e+06
# mean               7.078597e-01    6.347114e+00     1.034174e+00
# std                4.547467e-01    3.526090e+00     3.557418e-01
# ...

# %% [markdown]
# La configuración predeterminada de "describir" omite variables de tipo objeto. Podemos aplicar el método "describir" sobre las variables de tipo 'objeto' de la siguiente manera:

# %%
df.describe(include=['object'])
# Out:
#             sex marital_status injury_at_work method_of_disposition  autopsy  \
# count   1048575        1048575        1048575               1048575  1048575
# unique        2              5              3                     7        3
# top           M              M              U                     B        N
# freq     525792         378634         965266                384579   923676
#
#        icd_code_10th_revision entity_condition_1 entity_condition_2  \
# count                 1048575            1048575             799741
# unique                   3201               3244               7937
# top                      I251             11I469             21I251
# freq                    75821             146400              51627
#
#        entity_condition_3 entity_condition_4  ... record_condition_8  \
# count              546059             315780  ...              12818
# unique              11030              11968  ...                861
# ...

# %% [markdown]
# <p>Value Counts es una buena manera de entender cuántas unidades de cada característica/variable tenemos. Podemos aplicar el método "value_counts" en la columna "drive-wheels". No olvide que el método "value_counts" solo funciona en series de pandas, no en marcos de datos de pandas. Como resultado, solo incluimos un corchete <code>df['sexo']</code>, no dos corchetes <code>df[['sexo']]</code>.</p>

# %%
df['sex'].value_counts()
# Out:
# M    525792
# F    522783
# Name: sex, dtype: int64

# %% [markdown]
# Podemos convertir la serie a un marco de datos de la siguiente manera:

# %% [markdown]
# Repitamos los pasos anteriores, pero guardemos los resultados en el marco de datos "sex_counts" y cambiemos el nombre de la columna 'sex' a 'value_counts'.

# %%
sex_counts = df['sex'].value_counts().to_frame()
sex_counts.rename(columns={'sex': 'value_counts'}, inplace=True)
sex_counts
# Out:
#    value_counts
# M        525792
# F        522783

# %% [markdown]
# Ahora cambiemos el nombre del índice a 'Sex':

# %%
sex_counts.index.name = 'sex'
sex_counts
# Out:
#      value_counts
# sex
# M          525792
# F          522783

# %% [markdown]
# <p>Después de examinar los recuentos de valor del sexo, vemos que sexo puede ser beuna variable predictiva debido a que contamos con valores muy similares hablando Masculino y Femenino, si fueran F:3 y M: 98 tendriamos un sesgo para esta variable.</p>

# %% [markdown]
# <h2 id="basic_grouping">4. Conceptos básicos de agrupación</h2>

# %% [markdown]
# <p>El método "groupby" agrupa datos por diferentes categorías. Los datos se agrupan en función de una o varias variables, y el análisis se realiza en los grupos individuales.</p>
#
# <p>Por ejemplo, agrupemos por la variable "sex". Vemos que hay 2 categorías diferentes de ruedas motrices.</p>

# %%
df['sex'].unique()
# Out:
# array(['M', 'F'], dtype=object)

# %% [markdown]
# <p>Si queremos saber, en promedio, qué tipo de sexo es más valiosa, podemos agrupar "sex" y luego promediarlas.</p>
#
# <p>Podemos seleccionar las columnas 'drive-wheels', 'edad' y 'tipo', y luego asignarlas a la variable "df_group_one".</p>

# %%
df_group_one = df[['sex','detail_age_type','resident_status']]

# %% [markdown]
# Luego podemos calcular el sexo promedio para cada una de las diferentes categorías de datos.

# %%
# grouping results
df_group_one = df_group_one.groupby(['sex'],as_index=False).mean()
df_group_one
# Out:
#   sex  detail_age_type  resident_status
# 0   F         1.030144         1.207465
# 1   M         1.038180         1.244043

# %% [markdown]
# <p>Según nuestros datos, parece que el sexo Femenino y Masculino estan muy parejos en edad y estatus.</p>
#
# <p>También puede agrupar por múltiples variables. Por ejemplo, agrupemos por 'ruedas motrices' y 'estilo de carrocería'. Esto agrupa el marco de datos por la combinación única de 'ruedas motrices' y 'estilo de carrocería'. Podemos almacenar los resultados en la variable 'grouped_test1'.</p>

# %%
# grouping results
df_gptest = df[['sex','resident_status','detail_age_type']]
grouped_test1 = df_gptest.groupby(['sex','resident_status'],as_index=False).mean()
grouped_test1
# Out:
#   sex  resident_status  detail_age_type
# 0   F                1         1.024325
# 1   F                2         1.056424
# 2   F                3         1.047917
# 3   F                4         1.234017
# 4   M                1         1.031238
# 5   M                2         1.065407
# 6   M                3         1.051425
# 7   M                4         1.193866

# %% [markdown]
# <p>Estos datos agrupados son mucho más fáciles de visualizar cuando se convierten en una tabla dinámica. Una tabla dinámica es como una hoja de cálculo de Excel, con una variable a lo largo de la columna y otra a lo largo de la fila. Podemos convertir el marco de datos en una tabla dinámica usando el método "pivote" para crear una tabla dinámica a partir de los grupos.</p>
#
# <p>En este caso, dejaremos la variable sex como las filas de la tabla y pivotaremos el estilo de la resident_status para que se convierta en las columnas de la tabla:</p>

# %%
grouped_pivot = grouped_test1.pivot(index='sex',columns='resident_status')
grouped_pivot
# Out:
#                 detail_age_type
# resident_status               1         2         3         4
# sex
# F                      1.024325  1.056424  1.047917  1.234017
# M                      1.031238  1.065407  1.051425  1.193866

# %% [markdown]
# <p>A menudo, no tendremos datos para algunas de las celdas dinámicas. Podemos completar estas celdas faltantes con el valor 0, pero también se podría usar cualquier otro valor. Cabe mencionar que los datos faltantes son un tema bastante complejo y constituyen un curso completo por sí solo.</p>

# %%
grouped_pivot = grouped_pivot.fillna(0) #fill missing values with 0
grouped_pivot
# Out:
#                 detail_age_type
# resident_status               1         2         3         4
# sex
# F                      1.024325  1.056424  1.047917  1.234017
# M                      1.031238  1.065407  1.051425  1.193866

# %% [markdown]
# <p>A menudo, no tendremos datos para algunas de las celdas dinámicas. Podemos completar estas celdas faltantes con el valor 0, pero también se podría usar cualquier otro valor. Cabe mencionar que los datos faltantes son un tema bastante complejo y constituyen un curso completo por sí solo.</p>
